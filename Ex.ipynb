# %% [markdown]
# #**Lista de Exercícios**

# %% [markdown]
# ##Exercício 1
# Escreva um programa que peça ao usuário para digitar seu nome e, em seguida, imprima uma mensagem de boas-vindas com o nome fornecido.

# %%
nome = input("Qual é o seu nome ?: ")
print(f"Olá {nome}, Seja bem vindo(a)!")
# Out:
# Qual é o seu nome ?: Mika
# Olá Mika, Seja bem vindo(a)!

# %% [markdown]
# ## Exercício 2
# Crie duas variáveis, num_1 e num_2, e atribua a elas valores inteiros. Calcule a soma, subtração, multiplicação e divisão dessas variáveis e imprima os resultados.

# %%
num_1 = 20
num_2 = 5

print(f" {num_1} + {num_2} é igual a:  {num_1 + num_2} ")
print(f" {num_1} - {num_2} é igual a:  {num_1 - num_2} ")
print(f" {num_1} / {num_2} é igual a:  {num_1 / num_2} ")
print(f" {num_1} * {num_2} é igual a:  {num_1 * num_2}")
# Out:
#  20 + 5 é igual a:  25
#  20 - 5 é igual a:  15
#  20 / 5 é igual a:  4.0
#  20 * 5 é igual a:  100

# %% [markdown]
# ## Exercício 3
#
# Crie uma variável chamada saldo com o valor 500.50 (float). Em seguida, crie uma variável saque com o valor 200.25 (float). Subtraia o saque do saldo e imprima o saldo final formatado para duas casas decimais.

# %%
saldo = 500.50
saque = 200.25
print(f"Saldo final = {saldo - saque:.2f}")
# Out:
# Saldo final = 300.25

# %% [markdown]
# ## Exercício 4
# Declare uma variável booleana chamada **tem_carteira_de_motorista** e atribua a ela o valor True. Imprima uma mensagem que diga "Pode dirigir" se a variável for verdadeira e "Não pode dirigir" caso contrário.

# %%
tem_carteira_de_motorista = True

if tem_carteira_de_motorista:
  print('Pode dirigir')
else:
  print('Não pode dirigir')
# Out:
# Pode dirigir

# %% [markdown]
# ##Exercício 5
# Crie duas variáveis:
#
# - idade_ana = 25
# - idade_leo = 30
#
#
# Use operadores de comparação para verificar se a idade de Ana é menor que a de Beto e imprima o resultado booleano.

# %%
idade_ana = 25
idade_leo = 30

if idade_ana < idade_leo:
  print(True)
else:
  print(False)
# Out:
# True

# %% [markdown]
# ##Exercício 6
#
#
# Receba um número inteiro do usuário e use o operador de módulo (%) para verificar se o número é par ou ímpar. Imprima o resultado.

# %%
num = int(input("Digite um número: "))

if num  % 2 == 0:
  print(f"  O número {num} é par!")
else:
  print(f"  O  número {num} é ímpar!")
# Out:
# Digite um número: 16
#   O número 16 é par!

# %% [markdown]
# ## Exercício 7
# Crie duas variáveis booleanas:
#
# - chovendo = True
# - guarda_chuva = False
#
# Use operadores lógicos para verificar se uma pessoa vai se molhar (se está chovendo E ela não tem guarda-chuva).

# %%
chovendo = True
guarda_chuva  = False
vai_se_molhar = chovendo and not guarda_chuva
print(f"A pessoa vai se molhar ? {vai_se_molhar}")
# Out:
# A pessoa vai se molhar ? True

# %% [markdown]
# ##Exercício 8
# Calcule a potência de 2 elevado a 10 e imprima o resultado.

# %%
num = 2
print(f" 2 elevado a 10 é igual  a : { num ** 10}")
# Out:
#  2 elevado a 10 é igual  a : 1024

# %% [markdown]
# ##Exercício 9
# Converta a string "2026" para um tipo inteiro e armazene-a em uma variável chamada ano. Em seguida, some 1 a essa variável e imprima o novo ano.

# %%
ano_str ="2026"
ano_int= int(ano_str)
print(f" Ano novo é igual : {ano_int + 1} ")
# Out:
#  Ano novo é igual : 2027

# %% [markdown]
# ##Exercício 10
# Crie a string:
#
# frase = "     Python é uma linguagem poderosa e estou aprendendo   ".
#
# Remova os espaços em branco do início e do fim da string e imprima a nova string.

# %%
frase = "    Python é uma linguagem poderosa e estou aprendendo.    "
print(frase.strip())
# Out:
# Python é uma linguagem poderosa e estou aprendendo.

# %% [markdown]
# ## Exercício 11
# Na string do exercício anterior (já sem os espaços), converta toda a frase para letras maiúsculas.

# %%
frase = "Python é uma lnguagem poderosa e estou aprendendo."
print(frase.upper())
# Out:
# PYTHON É UMA LNGUAGEM PODEROSA E ESTOU APRENDENDO.

# %% [markdown]
# ##Exercício 12
# Substitua a palavra "poderosa" por "incrível".

# %%
frase = " Python é uma linguagem poderosa e estou aprendendo."
print (frase.replace("poderosa","Incrível"))
# Out:
#  Python é uma linguagem Incrível e estou aprendendo.

# %% [markdown]
# ##Exercício 13
# Verifique e imprima o número total de caracteres na string frase.

# %%
frase = "Python é uma linguagem poderosa e estou aprendendo."
print(f" a Frase possui {len(frase)} caracteres ")
# Out:
#  a Frase possui 51 caracteres

# %% [markdown]
# ##Exercício 14
# Use fatiamento (slicing) para extrair e imprimir apenas a palavra "Python" da string frase.

# %%
frase ="Python é uma linguagem poderosa e estou aprendendo"
print(f"{frase[0:6]}")
# Out:
# Python

# %% [markdown]
# ##Exercício 15
# Crie uma lista chamada compras com os seguintes itens: "arroz", "feijão", "macarrão", "carne". Imprima a lista.

# %%
lista_compras = ["arroz", "feijão", "macarrão", "carne"]
print(lista_compras)
# Out:
# ['arroz', 'feijão', 'macarrão', 'carne']

# %% [markdown]
# ##Exercício 16
# Adicione o item "leite" ao final da lista compras e imprima a lista atualizada.

# %%
lista_compras= ["arroz","feijão","macarrão","carne"]
lista_compras.append('leite')
print(lista_compras)
# Out:
# ['arroz', 'feijão', 'macarrão', 'carne', 'leite']

# %% [markdown]
# ## Exercício 17
# Acesse e imprima o segundo item da lista compras.

# %%
lista_compras = ["arroz", "feijão", "macarrão", "carne"]
print(lista_compras[1])
# Out:
# feijão

# %% [markdown]
# ##Exercício 18
# Remova o item "macarrão" da lista compras e imprima a lista final.

# %%
lista_compras = ["arroz", "feijão", "macarrão", "carne"]
lista_compras.pop(2)
print(lista_compras)
# Out:
# ['arroz', 'feijão', 'carne']

# %%
lista_compras = ["arroz", "feijão", "macarrão", "carne"]
lista_compras.remove("macarrão")
print(lista_compras)
# Out:
# ['arroz', 'feijão', 'carne']

# %% [markdown]
# ## Exercício 19
# Crie uma lista de números de 1 a 5. Use uma função para calcular e imprimir o tamanho (número de elementos) dessa lista.

# %%
lista = [1,15,20,56]

def tamanho_lista(lista):
  return len(lista)

print(tamanho_lista(lista))
# Out:
# 4

# %% [markdown]
# ##Exercício 20
# Crie uma tupla chamada meses com os três primeiros meses do ano: "Janeiro", "Fevereiro", "Março".

# %%
meses = ("Janeiro","Fevereiro","Março")
print(meses)
# Out:
# ('Janeiro', 'Fevereiro', 'Março')

# %% [markdown]
# ##Exercício 21
# Acesse e imprima o primeiro mês da tupla meses.

# %%
meses = ("Janeiro","Fevereiro","Março")
print(meses[0])
# Out:
# Janeiro

# %% [markdown]
# ## Exercício 22
# Crie um dicionário chamado filme com as seguintes chaves e valores:
#
# - titulo = "Jestem",
# - ano = 2005
# - diretor = "Dorota Kedzierzawska"

# %%
filme = {
    "Título": "Jestem",
    "Ano": 2005,
    "Diretor": "Dorota Kedzierzawska"
}
print(filme)
# Out:
# {'Título': 'Jestem', 'Ano': 2005, 'Diretor': 'Dorota Kedzierzawska'}

# %% [markdown]
# ##Exercício 23
# Acesse e imprima o ano de lançamento do filme a partir do dicionário.

# %%
filme = {
    "Título": "Jestem",
    "Ano": 2005,
    "Diretor": "Dorota Kedzierzawska"
}
print(filme["Ano"])
# Out:
# 2005

# %% [markdown]
# ## Exercício 24
# Adicione uma nova chave genero com o valor "Drama" ao dicionário filme e imprima o dicionário completo.

# %%
filme["Gênero"] = "Drama"
print(filme)
# Out:
# {'Título': 'Jestem', 'Ano': 2005, 'Diretor': 'Dorota Kedzierzawska', 'Gênero': 'Drama'}

# %% [markdown]
# ##Exercício 25
# Modifique o valor da chave ano para 1973 e imprima o dicionário atualizado.

# %%
filme["Ano"] = 1973
print(f" O ano foi modificado com sucesso!{filme}")
# Out:
#  O ano foi modificado com sucesso!{'Título': 'Jestem', 'Ano': 1973, 'Diretor': 'Dorota Kedzierzawska', 'Gênero': 'Drama'}

# %% [markdown]
# ## Exercício 26
# Crie uma lista com os seguintes números: [1, 2, 2, 3, 4, 4, 5, 1]. Use um conjunto para remover os números duplicados e imprima o resultado.

# %%
lista = [1,2,2,3,4,4,5,1]
conjunto = set(lista)
print(conjunto)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ## Exercício 27
# Crie dois conjuntos:
#
# - set_a = {1, 2, 3, 4}
# - set_b = {3, 4, 5, 6}
#
# Encontre e imprima a interseção entre os dois conjuntos (os elementos que estão em ambos)

# %%
set_a = {1,2,3,4}
set_b = {3,4,5,6}
intersecao = set_a.intersection(set_b)
print(intersecao)
# Out:
# {3, 4}

# %% [markdown]
# ## Exercício 28
# Escreva um programa que peça ao usuário para digitar sua altura em metros (ex: 1.75) e seu peso em quilogramas (ex: 68.5). Calcule o Índice de Massa Corporal (IMC) usando a fórmula IMC = peso / (altura * altura) e imprima o resultado formatado com duas casas decimais.

# %%
altura = float(input("Digite sua altura:"))
peso = float(input("Digite seu peso:"))
imc = peso / (altura  * altura)
print(f"O seu IMC é {imc:.2f}")
# Out:
# Digite sua altura:1.53
# Digite seu peso:40
# O seu IMC é 17.09
